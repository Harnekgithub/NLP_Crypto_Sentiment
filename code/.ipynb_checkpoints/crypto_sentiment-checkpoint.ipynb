# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
from nltk.stem import WordNetLemmatizer  
import spacy

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\harne\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_article = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="publishedAt"
)
bitcoin_article["articles"][0]
# Out:
# {'source': {'id': None, 'name': 'The Mac Observer'},
#  'author': 'Charlotte Henry',
#  'title': 'Tim Cook Dismisses Idea Apple Will Accept Payment in Cryptocurrency',
#  'description': 'Tim Cook dismissed the idea that Apple will accept cryptocurrency in exchange for products during an\xa0appearance at the Dealbook conference. He also said the company would not buy it with corporate funds. However, the Apple CEO did reveal that he personally ow…',
#  'url': 'https://www.macobserver.com/news/tim-cook-dismisses-idea-apple-will-cryptocurrency/',
#  'urlToImage': 'https://www.macobserver.com/wp-content/uploads/2021/11/Tim-Cook-Bitcoin-1024x538.png',
#  'publishedAt': '2021-11-09T16:21:15Z',
#  'content': 'Tim Cook dismissed the idea that Apple will accept cryptocurrency in exchange for products during an\xa0appearance at the Dealbook conference. He also said the company would not buy it with corporate fu… [+959 chars]'}

# %%
# Fetch the Ethereum news articles
ethereum_article = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="publishedAt"
)
ethereum_article["articles"][0]
# Out:
# {'source': {'id': None, 'name': 'The Mac Observer'},
#  'author': 'Charlotte Henry',
#  'title': 'Tim Cook Dismisses Idea Apple Will Accept Payment in Cryptocurrency',
#  'description': 'Tim Cook dismissed the idea that Apple will accept cryptocurrency in exchange for products during an\xa0appearance at the Dealbook conference. He also said the company would not buy it with corporate funds. However, the Apple CEO did reveal that he personally ow…',
#  'url': 'https://www.macobserver.com/news/tim-cook-dismisses-idea-apple-will-cryptocurrency/',
#  'urlToImage': 'https://www.macobserver.com/wp-content/uploads/2021/11/Tim-Cook-Bitcoin-1024x538.png',
#  'publishedAt': '2021-11-09T16:21:15Z',
#  'content': 'Tim Cook dismissed the idea that Apple will accept cryptocurrency in exchange for products during an\xa0appearance at the Dealbook conference. He also said the company would not buy it with corporate fu… [+959 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
bt_sentiments = []

for article in bitcoin_article["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bt_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass    
# Create DataFrame
bt_sentiment_df = pd.DataFrame(bt_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bt_sentiment_df = bt_sentiment_df[cols]

bt_sentiment_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-11-09  Tim Cook dismissed the idea that Apple will ac...    0.3818
# 1  2021-11-09  Apple CEO Tim Cook said he owns cryptocurrency...    0.4019
# 2  2021-11-09  United Kingdom-based crypto mining company Arg...    0.4215
# 3  2021-11-09  From a dodgy digital currency inspired by Netf...    0.3182
# 4  2021-11-09  The metaverse is a virtual world in which user...    0.0000
#
#    positive  negative  neutral
# 0     0.071     0.000    0.929
# 1     0.076     0.000    0.924
# 2     0.080     0.000    0.920
# 3     0.148     0.113    0.739
# 4     0.000     0.000    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
ether_sentiments = []

for article in ethereum_article["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiments = analyzer.polarity_scores(text)
        compound = sentiments["compound"]
        pos = sentiments["pos"]
        neu = sentiments["neu"]
        neg = sentiments["neg"]
        
        ether_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
          
        })
        
    except AttributeError:
        pass    

# Create DataFrame
ether_sentiment_df = pd.DataFrame(ether_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ether_sentiment_df = ether_sentiment_df[cols]

ether_sentiment_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-11-09  CryptocurrencyBitcoin and Ether hit another ne...    0.0000
# 1  2021-11-09  PLANO, Texas, Nov. 5, 2021 /PRNewswire/ -- Car...    0.1280
# 2  2021-11-09  Taken from the autumn 2021 issue of Dazed. You...    0.1531
# 3  2021-11-09  London, England, 9th November, 2021, \r\nCloud...    0.0000
# 4  2021-11-09  M&amp;M Q2 standalone net surges over 8-fold t...    0.3182
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.048     0.000    0.952
# 2     0.118     0.127    0.756
# 3     0.000     0.000    1.000
# 4     0.067     0.000    0.933

# %%
# Describe the Bitcoin Sentiment
bt_desc = bt_sentiment_df.describe()
bt_positive_mean = bt_desc.loc['mean'].positive
bt_desc
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.105763    0.068490    0.039720    0.891820
# std      0.386850    0.072807    0.065737    0.092946
# min     -0.920100    0.000000    0.000000    0.625000
# 25%     -0.029800    0.000000    0.000000    0.835000
# 50%      0.089950    0.065000    0.000000    0.917500
# 75%      0.345300    0.092500    0.065250    0.957750
# max      0.950100    0.375000    0.370000    1.000000

# %%
# Describe the Ethereum Sentiment
ether_desc = ether_sentiment_df.describe()
ether_positive_mean = ether_desc.loc['mean'].positive
ether_desc
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.222317    0.073290    0.020420    0.906270
# std      0.334619    0.062622    0.040683    0.070693
# min     -0.796400    0.000000    0.000000    0.756000
# 25%      0.000000    0.000000    0.000000    0.849000
# 50%      0.261600    0.068000    0.000000    0.919500
# 75%      0.480400    0.125250    0.000000    0.960500
# max      0.850200    0.216000    0.218000    1.000000

# %%
print(f"\033[1m Mean postive score for Bitcoin articles is \033[92m{bt_positive_mean} \033[0m")
print(f"\033[1m Mean postive score for Ethereum articles is \033[92m{ether_positive_mean}\033[0m")
print(f"\033[1m The highest compound score for Bitcoin articles is \033[92m{bt_sentiment_df.describe().loc['max'].compound}\033[0m")
print(f"\033[1m The highest compound score for Ethereum articles is \033[92m{ether_sentiment_df.describe().loc['max'].compound}\033[0m")
print(f"\033[1m The highest positive score for Bitcoin articles is \033[92m{bt_sentiment_df.describe().loc['max'].positive}\033[0m")
print(f"\033[1m The highest positive score for Ethereum articles is \033[92m{ether_sentiment_df.describe().loc['max'].positive}\033[0m")
# Out:
#  Mean postive score for Bitcoin articles is 0.04554000000000001
#  Mean postive score for Ethereum articles is 0.06981000000000001
#  The highest compound score for Bitcoin articles is 0.9501
#  The highest compound score for Ethereum articles is 0.9165
#  The highest positive score for Bitcoin articles is 0.359
#  The highest positive score for Ethereum articles is 0.38

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum has the highest mean postive score of 0.06981000000000001
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin has the highest compound score of 0.9501
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the highest positive score of 0.38

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw  = set(stopwords.words('english'))
print(sw)
# Out:
# {'isn', "shan't", 'will', 'was', 'under', 'should', 'out', 'our', 'are', 'themselves', 'were', 'such', "that'll", "hasn't", 'its', 'd', "isn't", 'after', 'there', 'his', 'have', 'whom', 'her', 'yourselves', 'once', 'wouldn', 'doesn', 'ourselves', 'why', 'hers', "didn't", 'in', 'where', 'hasn', "won't", 'your', 'that', 'own', "she's", 'too', 'until', 'weren', 'didn', 'by', 'be', 'between', 'all', 'haven', 'herself', 'has', 'now', 'while', "doesn't", 'yourself', 'above', 'o', 'hadn', 'and', "shouldn't", 'so', 'myself', 'couldn', 'does', 'with', 'no', 'mightn', 'i', 'these', 'on', 'just', 'here', "couldn't", 'my', 'their', 'ain', 'is', "you'll", 'or', 'below', 'the', 'off', 'having', 'being', 'needn', 'can', "it's", 'other', "you're", 'through', 'from', 'ours', 'mustn', 'shan', 'him', "you'd", 'y', 'an', 'he', 'aren', "mustn't", 'you', 'himself', 'she', 'wasn', 'a', 'very', 'both', "should've", 'than', 'then', 've', 'of', 'did', 'which', 'few', 'yours', "wouldn't", 'as', 'more', 't', 'they', 'ma', 'only', "aren't", 'doing', 'to', 'before', 're', 'had', 'we', 'any', 'if', 'into', 'because', 'won', 'll', 'up', "weren't", 'them', 'at', 'down', 'theirs', 'do', 'm', 'but', 'not', "mightn't", 's', "haven't", 'nor', "don't", 'it', 'against', 'when', 'each', 'this', 'me', 'been', 'shouldn', 'itself', 'what', 'who', 'further', "needn't", "hadn't", 'about', 'during', 'over', 'don', "you've", 'how', 'for', 'those', 'some', "wasn't", 'again', 'am', 'same', 'most'}

# %%
# Expand the default stopwords list if necessary
cust_sw = {'I','volatile','fake'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    sw  = set(stopwords.words('english'))
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
       
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lemmatized = [lemmatizer.lemmatize(word) for word in words]
       
    # Convert the words to lowercase
    words_lower = [word.lower() for word in lemmatized ]
    
    # Remove the stop words
    lem_words = [word for word in words_lower if word.lower() not in sw.union(cust_sw)]
    
    return lem_words

# %%
# Create a new tokens column for Bitcoin
bt_sentiment_df['tokens'] = bt_sentiment_df.text.apply(tokenizer)
bt_sentiment_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-11-09  Robinhood says millions of customers data was ...   -0.4939
# 1  2021-11-09  crypto coins circle\r\nNurphoto\r\nInvestors h...    0.2732
# 2  2021-11-09  CryptocurrencyBitcoin and Ether hit another ne...    0.0000
# 3  2021-11-09  Patrons of restaurants including Bubba Gump Sh...    0.0000
# 4  2021-11-09  Officils t the United Sttes Immigrtion nd Cust...    0.6369
#
#    positive  negative  neutral  \
# 0     0.000     0.082    0.918
# 1     0.055     0.000    0.945
# 2     0.000     0.000    1.000
# 3     0.000     0.000    1.000
# 4     0.152     0.000    0.848
#
#                                               tokens
# 0  [robinhood, say, million, customer, data, wa, ...
# 1  [crypto, coin, circlenurphotoinvestors, poured...
# 2  [cryptocurrencybitcoin, ether, hit, another, n...
# 3  [patrons, restaurant, including, bubba, gump, ...
# 4  [officils, united, sttes, immigrtion, nd, cust...

# %%
# Create a new tokens column for Ethereum
ether_sentiment_df['tokens'] = ether_sentiment_df.text.apply(tokenizer)
ether_sentiment_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-11-09  CryptocurrencyBitcoin and Ether hit another ne...    0.0000
# 1  2021-11-09  PLANO, Texas, Nov. 5, 2021 /PRNewswire/ -- Car...    0.1280
# 2  2021-11-09  Taken from the autumn 2021 issue of Dazed. You...    0.1531
# 3  2021-11-09  London, England, 9th November, 2021, \r\nCloud...    0.0000
# 4  2021-11-09  M&amp;M Q2 standalone net surges over 8-fold t...    0.3182
#
#    positive  negative  neutral  \
# 0     0.000     0.000    1.000
# 1     0.048     0.000    0.952
# 2     0.118     0.127    0.756
# 3     0.000     0.000    1.000
# 4     0.067     0.000    0.933
#
#                                               tokens
# 0  [cryptocurrencybitcoin, ether, hit, another, n...
# 1  [plano, texas, nov, prnewswire, carnomaly, wor...
# 2  [taken, fromthe, autumn, issueof, dazed, canbu...
# 3  [london, england, th, november, cloud, monetiz...
# 4  [mampm, q, standalone, net, surge, fold, rs, c...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
bt_text = ' '.join(bt_sentiment_df.text)
bt_tokenized_text = tokenizer(bt_text)
bt_ngrams =  Counter(ngrams(bt_tokenized_text, 2))
#bt_ngrams

# %%
# Generate the Ethereum N-grams where N=2
ether_text = ' '.join(ether_sentiment_df.text)
ether_tokenized_text = tokenizer(ether_text)
ether_ngrams =  Counter(ngrams(ether_tokenized_text, 2))

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
#print(token_count(bt_tokenized_text))
token_count(bt_tokenized_text)
# Out:
# [('char', 91),
#  ('bitcoin', 34),
#  ('high', 24),
#  ('ha', 23),
#  ('new', 22),
#  ('market', 16),
#  ('tuesday', 16),
#  ('cryptocurrency', 15),
#  ('crypto', 14),
#  ('price', 14)]

# %%
# Use token_count to get the top 10 words for Ethereum
print(token_count(ether_tokenized_text))
token_count(ether_tokenized_text)
# Out:
# [('char', 96), ('bitcoin', 33), ('ha', 32), ('cryptocurrency', 25), ('new', 20), ('high', 20), ('market', 19), ('ethereum', 18), ('digital', 18), ('world', 15)]
# [('char', 96),
#  ('bitcoin', 33),
#  ('ha', 32),
#  ('cryptocurrency', 25),
#  ('new', 20),
#  ('high', 20),
#  ('market', 19),
#  ('ethereum', 18),
#  ('digital', 18),
#  ('world', 15)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(bt_text)
# render the plot
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(ether_text)
# render the plot
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
#!python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bt_txt_concat = ' '.join(bt_sentiment_df.text)

# %%
# Run the NER processor on all of the text
bt_doc = nlp(bt_txt_concat)

# Add a title to the document
bt_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bt_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robinhood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of customers data was stolen. The trading app said that a hacker breached its systems
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and stole the full names and email addresses of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of users, as part of a… [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +1922
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nurphoto
# Investors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have poured more money into crypto so far in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  than they did for the whole of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with record amounts flowing into bitcoin and ether, as well as smaller … [+2579 chars] CryptocurrencyBitcoin and Ether hit another new all-time high price on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Ether, the crypto token that underpins the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  network, rallied above $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (roughly Rs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lakh), acco… [+3744 chars] Patrons of restaurants including
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bubba Gump Shrimp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Morton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steakhouse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Restaurant giant… [+3174 chars] Officils t the United Sttes Immigrtion nd Customs Enforcements (ICE)
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Homelnd Security
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Thret ctors crrying out the mliciou… [+1760 chars] Taken from the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     autumn 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  issue of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dazed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Once upon a time, declaring an interest in trading on the stock market was a sure fire way to expose yourself a… [+6579 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The US Tresury Deprtment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  nnounced tody snctions ginst the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chtex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tresury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  lso snctioned the Russin-li… [+3150 chars] Bitcoin (BTC) could nail the now-popular $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     98,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>In its
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October

# %%
# List all Entities
entities = [ent.text + ' - ' + ent.label_  for ent in bt_doc.ents ]
print(entities)

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ether_txt_concat = ' '.join(ether_sentiment_df.text)

# %%
# Run the NER processor on all of the text
ether_doc = nlp(ether_txt_concat)

# Add a title to the document
ether_doc.user_data["Title"]="Ethereum NER"

# %%
# Render the visualization
displacy.render(ether_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">CryptocurrencyBitcoin and Ether hit another new all-time high price on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Ether, the crypto token that underpins the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  network, rallied above $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (roughly Rs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lakh), acco… [+3744 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PLANO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nov. 5, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  /PRNewswire/ --
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carnomaly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the world's leading automotive crypto company,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  announced their
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CARR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  token has launched on the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UniSwap
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cryptocurrency exchange, making it th… [+1741 chars] Taken from the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     autumn 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  issue of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dazed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Once upon a time, declaring an interest in trading on the stock market was a sure fire way to expose yourself a… [+6579 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cloud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  monetization application provider
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cudos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  is partnering with purpose driven esports organisation
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LDN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br> at its latest event,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     All Access Gaming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , at state-… [+4596 chars] M&amp;amp;M
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  standalone net surges over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8-fold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  to Rs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1,432
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; verti

# %%
# List all Entities
entities = [ent.text + ' - ' + ent.label_  for ent in ether_doc.ents ]
print(entities)

# %% [markdown]
# ---
